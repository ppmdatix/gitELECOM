# %%
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np

# %%
def gradient(x,y,alpha,offset):
    return [np.log(1-y) + alpha * np.log(1-y) - offset,
           x/(1-y) + (1-x)*alpha/(1-y)]

def iterate(x0,y0,n):
    global X, Y, Z, gradient
    x, y = x0, y0
    for _ in range(n):
        x = 0.01 * int(100*x)
        y =

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')



# Make data.
alpha = 1
X = np.arange(0, 1, 0.01)
Y =  np.arange(0, 1, 0.01)
X, Y = np.meshgrid(X, Y)
alpha = 1.5
offset = 2.5
L = - np.log(1-Y)
Z =  X * L + (1 - X)*(alpha*L +offset)



fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111, projection='3d')
# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=True, shade=False)

# Customize the z axis.
ax.set_zlim(-0.01, 10.1)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))


line = ax.plot([0.5,0.6], [0.5,0.6], [12,7], color="black")
# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.xlabel("Malveillance(traffic)", fontsize="x-large")
plt.ylabel("1 - D(traffic)", fontsize="x-large")
plt.savefig("images/3Dsurf.png")

plt.show()
plt.close()

# %%
x = np.arange(0, 1, 0.001)
plt.plot(x, -np.log(x), label="y = - log DG(x)")
plt.title("Fonction de cout classique")
plt.xlabel("Prediciton Discriminateur")
plt.legend()
plt.savefig("images/fct_cout_classique.png")
plt.show()
# Out:
# /home/peseux/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
